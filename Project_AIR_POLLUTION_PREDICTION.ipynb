# %% [markdown]
# <a href="https://colab.research.google.com/github/anusree-128/AIR-POLLUTION-PREDICTION/blob/main/Project_AIR_POLLUTION_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/DATA SCIENCE/MACHINE LEARNING-(ML)/PROJECT/updated_pollution_dataset.csv')

# %%
df.head(10)
# Out:
#    Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0         29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 1         28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2         23.1      74.7   26.7  33.8  24.4  12.6  1.63
# 3         27.1      39.1    6.1   6.3  13.5   5.3  1.15
# 4         26.5      70.7    6.9  16.0  21.9   5.6  1.01
# 5         39.4      96.6   14.6  35.5  42.9  17.9  1.82
# 6         41.7      82.5    1.7  15.8  31.1  12.7  1.80
# 7         31.0      59.6    5.0  16.8  24.2  13.6  1.38
# 8         29.4      93.8   10.3  22.7  45.1  11.8  2.03
# 9         33.2      80.5   11.1  24.4  32.0  15.3  1.69
#
#    Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                            6.3                 319    Moderate
# 1                            6.0                 611    Moderate
# 2                            5.2                 619    Moderate
# 3                           11.1                 551        Good
# ...

# %%
df.tail(10)
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 4990         46.8      93.8   11.8   25.4  33.8  28.7  3.27
# 4991         31.8      80.2   22.4   34.1  29.7   4.9  1.22
# 4992         29.8      56.7    6.8   14.0  23.0   4.5  1.10
# 4993         34.9      77.7   32.3   47.1  17.4  11.5  1.63
# 4994         31.1      61.0   27.1   31.1  13.0   3.8  0.98
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density Air Quality
# 4990                            3.7                 589   Hazardous
# 4991                            9.4                 580    Moderate
# 4992                           11.4                 567        Good
# ...

# %%
print(df.size)
print(df.shape)
print(df.ndim)
# Out:
# 50000
# (5000, 10)
# 2

# %%
df.describe()
# Out:
#        Temperature     Humidity        PM2.5         PM10          NO2  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     30.029020    70.056120    20.142140    30.218360    26.412100
# std       6.720661    15.863577    24.554546    27.349199     8.895356
# min      13.400000    36.000000     0.000000    -0.200000     7.400000
# 25%      25.100000    58.300000     4.600000    12.300000    20.100000
# 50%      29.000000    69.800000    12.000000    21.700000    25.300000
# 75%      34.000000    80.300000    26.100000    38.100000    31.900000
# max      58.600000   128.100000   295.000000   315.800000    64.900000
#
#                SO2           CO  Proximity_to_Industrial_Areas  \
# count  5000.000000  5000.000000                    5000.000000
# mean     10.014820     1.500354                       8.425400
# std       6.750303     0.546027                       3.610944
# min      -6.200000     0.650000                       2.500000
# ...

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO',
#        'Proximity_to_Industrial_Areas', 'Population_Density', 'Air Quality'],
#       dtype='object')

# %%
for i in df.columns:
  print(df[i].value_counts())
  print('*'*100)
  print(df[i].unique())
# Out:
# Temperature
# 26.8    45
# 26.7    43
# 29.4    42
# 27.4    41
# 26.3    41
#         ..
# 16.1     1
# 48.3     1
# 56.5     1
# 52.4     1
# 57.2     1
# Name: count, Length: 362, dtype: int64
# ****************************************************************************************************
# [29.8 28.3 23.1 27.1 26.5 39.4 41.7 31.  29.4 33.2 26.3 32.5 20.  28.6
#  22.3 32.  22.9 37.6 34.7 37.8 27.6 25.6 24.6 26.2 22.6 30.  29.6 52.5
#  44.7 23.3 35.4 29.7 21.8 27.7 27.5 28.  22.2 33.3 37.5 30.9 39.3 24.7
#  27.8 17.4 18.1 22.4 25.3 42.1 32.6 46.1 33.5 48.1 31.6 29.  24.9 20.8
#  28.2 21.5 17.5 58.6 28.1 25.  25.7 35.1 26.7 20.4 25.9 22.1 34.1 30.4
#  41.4 25.5 36.6 18.8 34.9 23.  21.4 32.3 33.1 29.9 29.3 23.9 23.7 21.9
#  44.9 27.  49.6 33.4 23.5 41.5 21.  31.3 46.8 24.1 22.5 29.5 33.  30.1
#  27.4 30.8 36.2 32.8 21.6 31.4 24.2 47.3 40.  29.2 20.1 42.6 33.7 30.7
#  37.3 28.9 25.2 30.2 35.6 32.4 35.  15.4 22.8 34.4 23.2 30.5 24.  32.1
# ...

# %%
df.isna().sum()
# Out:
# Temperature                      0
# Humidity                         0
# PM2.5                            0
# PM10                             0
# NO2                              0
# SO2                              0
# CO                               0
# Proximity_to_Industrial_Areas    0
# Population_Density               0
# Air Quality                      0
# dtype: int64

# %%
sum=df.duplicated().sum()

# %%
print(sum.item())
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Air Quality'] = df['Air Quality'].astype(str)
df['Air Quality'] = le.fit_transform(df['Air Quality'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Temperature                    5000 non-null   float64
#  1   Humidity                       5000 non-null   float64
#  2   PM2.5                          5000 non-null   float64
#  3   PM10                           5000 non-null   float64
#  4   NO2                            5000 non-null   float64
#  5   SO2                            5000 non-null   float64
#  6   CO                             5000 non-null   float64
#  7   Proximity_to_Industrial_Areas  5000 non-null   float64
#  8   Population_Density             5000 non-null   int64
#  9   Air Quality                    5000 non-null   int64
# dtypes: float64(8), int64(2)
# memory usage: 390.8 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for i in df.columns:
  sns.boxplot(x=df[i])
  plt.show()

# %%
df.corr()['Air Quality']
# Out:
# Temperature                      0.501446
# Humidity                         0.430633
# PM2.5                            0.268432
# PM10                             0.366493
# NO2                              0.521952
# SO2                              0.497263
# CO                               0.618933
# Proximity_to_Industrial_Areas   -0.715686
# Population_Density               0.432361
# Air Quality                      1.000000
# Name: Air Quality, dtype: float64

# %%
cor_mtrx=df.corr()
cor_mtrx
# Out:
#                                Temperature  Humidity     PM2.5      PM10  \
# Temperature                       1.000000  0.466456  0.323840  0.425690
# Humidity                          0.466456  1.000000  0.273366  0.359156
# PM2.5                             0.323840  0.273366  1.000000  0.973005
# PM10                              0.425690  0.359156  0.973005  1.000000
# NO2                               0.591969  0.491977  0.333004  0.439916
# SO2                               0.568082  0.459804  0.299582  0.401849
# CO                                0.685258  0.567540  0.395179  0.518895
# Proximity_to_Industrial_Areas    -0.589564 -0.479646 -0.315766 -0.425018
# Population_Density                0.481692  0.411630  0.278957  0.365734
# Air Quality                       0.501446  0.430633  0.268432  0.366493
#
#                                     NO2       SO2        CO  \
# Temperature                    0.591969  0.568082  0.685258
# ...

# %%
plt.figure(figsize=(11,8))
sns.heatmap(cor_mtrx, fmt='.2f', annot=True, linewidths=1, cmap='coolwarm', linecolor='black')
plt.title("Correlation Heatmap")
plt.show()

# %%
x=df.drop(['Air Quality'],axis=1)
y=df['Air Quality']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
ypred=knn.predict(x_test)

# %%
ypred
# Out:
# array([1, 0, 2, 1, 0, 3, 0, 0, 0, 2, 2, 0, 1, 0, 2, 0, 0, 0, 2, 3, 0, 0,
#        3, 2, 0, 3, 0, 0, 2, 2, 0, 3, 3, 2, 2, 2, 2, 2, 2, 0, 3, 2, 1, 0,
#        0, 2, 2, 3, 0, 0, 2, 0, 0, 0, 0, 2, 1, 2, 3, 0, 0, 0, 0, 2, 0, 3,
#        3, 0, 2, 2, 0, 0, 3, 0, 0, 2, 2, 2, 0, 0, 0, 1, 3, 0, 2, 2, 1, 2,
#        2, 3, 2, 0, 0, 3, 3, 2, 2, 0, 3, 0, 1, 2, 3, 2, 1, 0, 0, 0, 2, 0,
#        2, 2, 2, 0, 2, 3, 1, 0, 0, 0, 2, 2, 2, 2, 3, 0, 2, 2, 0, 0, 2, 0,
#        3, 0, 2, 2, 0, 0, 2, 0, 0, 2, 0, 0, 2, 2, 1, 0, 2, 2, 3, 3, 2, 0,
#        0, 3, 2, 2, 2, 2, 3, 0, 2, 1, 3, 2, 0, 0, 0, 0, 2, 3, 0, 1, 0, 0,
#        0, 2, 0, 3, 3, 0, 2, 0, 0, 3, 0, 0, 0, 0, 1, 3, 2, 3, 2, 2, 1, 3,
#        3, 3, 0, 0, 2, 2, 0, 0, 0, 2, 0, 0, 0, 0, 3, 2, 2, 2, 2, 3, 0, 1,
#        0, 2, 0, 2, 0, 2, 1, 3, 2, 0, 0, 0, 0, 0, 0, 3, 0, 3, 3, 2, 2, 0,
#        2, 1, 0, 2, 0, 0, 0, 0, 2, 2, 0, 3, 3, 3, 0, 0, 1, 3, 0, 2, 0, 3,
#        0, 2, 3, 3, 2, 0, 2, 2, 2, 0, 3, 3, 2, 0, 3, 0, 1, 0, 0, 3, 2, 0,
# ...

# %%
training_score=knn.score(x_train,y_train)
testing_score=knn.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.944
# 0.935

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,ypred))
print(precision_score(y_test,ypred,average='weighted'))
print(recall_score(y_test,ypred,average='weighted'))
print(f1_score(y_test,ypred,average='weighted'))
print(confusion_matrix(y_test,ypred))
print(classification_report(y_test,ypred))
# Out:
# 0.935
# 0.9376255421391857
# 0.935
# 0.9341646885797922
# [[409   0   0   0]
#  [  0  80   0  31]
#  [  3   0 282   9]
#  [  0   4  18 164]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       409
#            1       0.95      0.72      0.82       111
#            2       0.94      0.96      0.95       294
#            3       0.80      0.88      0.84       186
#
#     accuracy                           0.94      1000
#    macro avg       0.92      0.89      0.90      1000
# weighted avg       0.94      0.94      0.93      1000

# %% [markdown]
# DESICION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()


dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ypred=dt.predict(x_test)

# %%
training_score=dt.score(x_train,y_train)
testing_score=dt.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 1.0
# 0.917

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,ypred))
print(precision_score(y_test,ypred,average='weighted'))
print(recall_score(y_test,ypred,average='weighted'))
print(f1_score(y_test,ypred,average='weighted'))
print(confusion_matrix(y_test,ypred))
print(classification_report(y_test,ypred))
# Out:
# 0.917
# 0.9199715733338099
# 0.917
# 0.9179626461074449
# [[408   0   1   0]
#  [  0  94   0  17]
#  [  3   1 267  23]
#  [  0  29   9 148]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       409
#            1       0.76      0.85      0.80       111
#            2       0.96      0.91      0.94       294
#            3       0.79      0.80      0.79       186
#
#     accuracy                           0.92      1000
#    macro avg       0.88      0.89      0.88      1000
# weighted avg       0.92      0.92      0.92      1000

# %% [markdown]
# Here decision tree is overfit.so Hyperparameter tuning can be done

# %%
help(dt)
# Out:
# Help on DecisionTreeClassifier in module sklearn.tree._classes object:
#
# class DecisionTreeClassifier(sklearn.base.ClassifierMixin, BaseDecisionTree)
#  |  DecisionTreeClassifier(*, criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0, monotonic_cst=None)
#  |
#  |  A decision tree classifier.
#  |
#  |  Read more in the :ref:`User Guide <tree>`.
#  |
#  |  Parameters
#  |  ----------
#  |  criterion : {"gini", "entropy", "log_loss"}, default="gini"
#  |      The function to measure the quality of a split. Supported criteria are
#  |      "gini" for the Gini impurity and "log_loss" and "entropy" both for the
#  |      Shannon information gain, see :ref:`tree_mathematical_formulation`.
#  |
#  |  splitter : {"best", "random"}, default="best"
# ...

# %%
param_grid = { 'max_depth': [3, 4, 5, 6, 7, 8, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 4, 6],
    'max_features': [None, 'sqrt', 'log2']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(
    estimator=dt,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1)

grid_search.fit(x_train, y_train)

print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 336 candidates, totalling 1680 fits
# Best Parameters: {'max_depth': None, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 5}

# %%
dt=DecisionTreeClassifier(max_depth=None, max_features=None, min_samples_leaf=6, min_samples_split=5)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=6, min_samples_split=5)

# %%
ypred=dt.predict(x_test)

# %%
training_score=dt.score(x_train,y_train)
testing_score=dt.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.96
# 0.925

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,ypred))
print(precision_score(y_test,ypred,average='weighted'))
print(recall_score(y_test,ypred,average='weighted'))
print(f1_score(y_test,ypred,average='weighted'))
print(confusion_matrix(y_test,ypred))
print(classification_report(y_test,ypred))
# Out:
# 0.925
# 0.9262135484747785
# 0.925
# 0.9251303006631002
# [[409   0   0   0]
#  [  0  95   0  16]
#  [  2   0 277  15]
#  [  0  30  12 144]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       409
#            1       0.76      0.86      0.81       111
#            2       0.96      0.94      0.95       294
#            3       0.82      0.77      0.80       186
#
#     accuracy                           0.93      1000
#    macro avg       0.88      0.89      0.89      1000
# weighted avg       0.93      0.93      0.93      1000

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred=lr.predict(x_test)

# %%
training_score=lr.score(x_train,y_train)
testing_score=lr.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.94325
# 0.947

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,ypred))
print(precision_score(y_test,ypred,average='weighted'))
print(recall_score(y_test,ypred,average='weighted'))
print(f1_score(y_test,ypred,average='weighted'))
print(confusion_matrix(y_test,ypred))
print(classification_report(y_test,ypred))
# Out:
# 0.947
# 0.94786117285737
# 0.947
# 0.94698231901661
# [[409   0   0   0]
#  [  0  91   0  20]
#  [  0   0 282  12]
#  [  0   8  13 165]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       409
#            1       0.92      0.82      0.87       111
#            2       0.96      0.96      0.96       294
#            3       0.84      0.89      0.86       186
#
#     accuracy                           0.95      1000
#    macro avg       0.93      0.92      0.92      1000
# weighted avg       0.95      0.95      0.95      1000

# %%
import pickle
pickle.dump(lr,open('model_lr.sav','wb'))

# %%
import pickle
pickle.dump(scaler,open('scaler.sav','wb'))

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=svm.predict(x_test)

# %%
training_score=svm.score(x_train,y_train)
testing_score=svm.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.9565
# 0.942

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.942
# 0.9423663104259715
# 0.942
# 0.9418998771312675
# [[409   0   0   0]
#  [  0  90   0  21]
#  [  0   0 282  12]
#  [  0  11  14 161]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       409
#            1       0.89      0.81      0.85       111
#            2       0.95      0.96      0.96       294
#            3       0.83      0.87      0.85       186
#
#     accuracy                           0.94      1000
#    macro avg       0.92      0.91      0.91      1000
# weighted avg       0.94      0.94      0.94      1000

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)

# %%
training_score=rf.score(x_train,y_train)
testing_score=rf.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 1.0
# 0.96

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.96
# 0.9602768508098057
# 0.96
# 0.960074522456019
# [[408   0   1   0]
#  [  0  99   0  12]
#  [  0   0 284  10]
#  [  0   8   9 169]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       409
#            1       0.93      0.89      0.91       111
#            2       0.97      0.97      0.97       294
#            3       0.88      0.91      0.90       186
#
#     accuracy                           0.96      1000
#    macro avg       0.94      0.94      0.94      1000
# weighted avg       0.96      0.96      0.96      1000

# %%
from scipy.stats import randint

# %%
param_dist={'n_estimators':[10,15,20,25,30,35,40,45,50],'max_depth':[3,4,5,6,7,8,9,10],'max_features': randint (1,11),'min_samples_split':randint(2,11),'criterion':['gini','entropy']}

# %%
rfc=RandomForestClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
randomCV=RandomizedSearchCV(rfc,param_distributions=param_dist,n_iter=50,cv=10,random_state=42)

# %%
randomCV.fit(x_train,y_train)
print(randomCV.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'max_features': 2, 'min_samples_split': 2, 'n_estimators': 40}

# %%
print(randomCV.score(x_test,y_test))
# Out:
# 0.954

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(criterion='gini', max_depth=10, max_features=2, min_samples_split=2, n_estimators=40)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, max_features=2, n_estimators=40)

# %%
y_pred=rf.predict(x_test)

# %%
training_score=rf.score(x_train,y_train)
testing_score=rf.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.98725
# 0.949

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.949
# 0.9508835576114382
# 0.949
# 0.9490474488783005
# [[409   0   0   0]
#  [  0  88   0  23]
#  [  0   0 282  12]
#  [  0   8   8 170]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       409
#            1       0.92      0.79      0.85       111
#            2       0.97      0.96      0.97       294
#            3       0.83      0.91      0.87       186
#
#     accuracy                           0.95      1000
#    macro avg       0.93      0.92      0.92      1000
# weighted avg       0.95      0.95      0.95      1000

# %% [markdown]
# GAUSSIAN NB

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb.predict(x_test)

# %%
training_score=nb.score(x_train,y_train)
testing_score=nb.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.92625
# 0.926

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.926
# 0.9279933362745116
# 0.926
# 0.9262496659774104
# [[405   0   4   0]
#  [  0  85   0  26]
#  [  1   1 275  17]
#  [  0  11  14 161]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       409
#            1       0.88      0.77      0.82       111
#            2       0.94      0.94      0.94       294
#            3       0.79      0.87      0.83       186
#
#     accuracy                           0.93      1000
#    macro avg       0.90      0.89      0.89      1000
# weighted avg       0.93      0.93      0.93      1000

# %% [markdown]
# BERNOULLI NAIVE BAYES

# %%
from sklearn.naive_bayes import BernoulliNB
bnb=BernoulliNB()
bnb.fit(x_train, y_train)

bnb.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
y_pred=bnb.predict(x_test)

# %%
training_score=bnb.score(x_train,y_train)
testing_score=bnb.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.81975
# 0.833

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.833
# 0.833578678421175
# 0.833
# 0.8324123550629652
# [[408   0   1   0]
#  [  0  67   3  41]
#  [ 15   1 237  41]
#  [  0  29  36 121]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       409
#            1       0.69      0.60      0.64       111
#            2       0.86      0.81      0.83       294
#            3       0.60      0.65      0.62       186
#
#     accuracy                           0.83      1000
#    macro avg       0.78      0.76      0.77      1000
# weighted avg       0.83      0.83      0.83      1000

# %% [markdown]
# ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
from sklearn.linear_model import LogisticRegression
adaboost_custom=AdaBoostClassifier(n_estimators=10,estimator=LogisticRegression())

# %%
adaboost_custom.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(estimator=LogisticRegression(), n_estimators=10)

# %%
y_pred=adaboost_custom.predict(x_test)

# %%
training_score=adaboost_custom.score(x_train,y_train)
testing_score=adaboost_custom.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.872
# 0.86

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.86
# 0.9003452899506632
# 0.86
# 0.856967641653779
# [[408   0   1   0]
#  [  0  45   0  66]
#  [ 12   0 229  53]
#  [  0   2   6 178]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       409
#            1       0.96      0.41      0.57       111
#            2       0.97      0.78      0.86       294
#            3       0.60      0.96      0.74       186
#
#     accuracy                           0.86      1000
#    macro avg       0.87      0.78      0.79      1000
# weighted avg       0.90      0.86      0.86      1000

# %%
import pandas as pd

results = {
    'Model': ['KNN', 'DecisionTree','Logistic Regression','SVM', 'Random Forest','GaussianNaiveBayes','BernoulliNaiveBayes','Adaboost'],
    'Accuracy': [0.93, 0.916, 0.94, 0.94,0.954,0.926,0.83,0.86],
    'Precision': [0.937, 0.919, 0.94, 0.94,0.954,0.927,0.83,0.90],
    'Recall': [0.935, 0.916, 0.94, 0.941,0.954,0.926,0.83,0.86],
    'F1-Score': [0.934, 0.916, 0.94, 0.948,0.953,0.926,0.83,0.85]    }

model_comparison = pd.DataFrame(results)


print(model_comparison)
# Out:
#                  Model  Accuracy  Precision  Recall  F1-Score
# 0                  KNN     0.930      0.937   0.935     0.934
# 1         DecisionTree     0.916      0.919   0.916     0.916
# 2  Logistic Regression     0.940      0.940   0.940     0.940
# 3                  SVM     0.940      0.940   0.941     0.948
# 4        Random Forest     0.954      0.954   0.954     0.953
# 5   GaussianNaiveBayes     0.926      0.927   0.926     0.926
# 6  BernoulliNaiveBayes     0.830      0.830   0.830     0.830
# 7             Adaboost     0.860      0.900   0.860     0.850

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.barplot(x='Model', y='Accuracy', data=model_comparison, palette='Set2')
plt.title('Model Accuracy Comparison')
plt.xticks(rotation=45)
plt.ylim(0.8, 1.0)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-78-1491055841>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Accuracy', data=model_comparison, palette='Set2')

# %% [markdown]
# From this it is highly accurate model is random forest but it is slightly overfit so best fit model is  logistic regression with 94% accuracy and same testing and training score.
